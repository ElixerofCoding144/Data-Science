# %% [markdown]
# <a href="https://colab.research.google.com/github/ElixerofCoding144/Data-Science/blob/main/NLP/YTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
link = 'https://www.youtube.com/watch?v=MY5SatbZMAo'

# %%
video_id = link.split('=')[1]

# %%
YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'duration': 7.0,
#   'start': 0.0,
#   'text': 'Translator: Riaki Poništ\nReviewer: Peter van de Ven'},
#  {'duration': 1.74, 'start': 9.07, 'text': 'Thank you so much.'},
#  {'duration': 1.809, 'start': 12.39, 'text': 'I am a journalist.'},
#  {'duration': 3.49,
#   'start': 14.539,
#   'text': 'My job is to talk to people\nfrom all walks of life,'},
#  {'duration': 1.68, 'start': 18.239, 'text': 'all over the world.'},
#  {'duration': 1.44, 'start': 19.999, 'text': 'Today, I want to tell you'},
#  {'duration': 4.301,
#   'start': 21.439,
#   'text': "why I decided to do this with my life\nand what I've learned."},
#  {'duration': 2.849,
#   'start': 26.58,
#   'text': 'My story begins in Caracas, Venezuela,'},
#  {'duration': 2.42,
#   'start': 29.479,
#   'text': 'in South America, where I grew up;'},
#  {'duration': 2.881,
#   'start': 32.119,
#   'text': 'a place that to me was,\nand always will be,'},
# ...

# %%
transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

# %%
transcript_list

# %%
transcript = transcript_list.find_transcript(['en'])
